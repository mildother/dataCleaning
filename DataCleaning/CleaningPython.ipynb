# %% [markdown]
# # Cleaning Data in Python

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the audible_uncleaned.csv file
audible = pd.read_csv('data/audible_uncleaned.csv')

# View the first rows of the dataframe
audible.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
# Load the audible_cleaned.csv file
audible2 = pd.read_csv('data/audible_cleaned.csv')

# View the first rows of the dataframe
audible2.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator  time releasedate language  stars  price  ratings
# 0      BillLobely   140  2008-04-08  English    5.0  468.0     34.0
# 1   RobbieDaymond   788  2018-01-05  English    4.5  820.0     41.0
# 2      DanRussell   123  2020-06-11  English    4.5  410.0     38.0
# 3  SoneelaNankani   676  2021-05-10  English    4.5  615.0     12.0
# 4  JesseBernstein   600  2010-01-13  English    4.5  820.0    181.0

# %%
# Inspect the columns' data types
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Task 2:
# Clean text data in Author and Narrator Columns

# %%
# Remove Writtenby: from the author column
audible['author'] = audible['author'].str.replace('Writtenby:', '')

# Remove Narratedby: from the narrator column
audible['narrator'] = audible['narrator'].str.replace('Narratedby:', '')

# Check the results
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      JesseBernstein              10 hrs    13-01-10  English
# ...               ...                 ...         ...      ...
# 87484    ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
# Get a glimpse of the stars column
audible.stars.sample(n=10)
# Out:
# 17782                 Not rated yet
# 77252                 Not rated yet
# 27610    5 out of 5 stars13 ratings
# 65171                 Not rated yet
# 73172                 Not rated yet
# 9918                  Not rated yet
# 46161                 Not rated yet
# 42311                 Not rated yet
# 81897                 Not rated yet
# 14785                 Not rated yet
# Name: stars, dtype: object

# %%
# Explore the values of the star column that aren't "Not rated yet"
audible[audible['stars'] != 'Not rated yet'].stars.sample(n=10)
# Out:
# 14320        4 out of 5 stars1 rating
# 64429    4.5 out of 5 stars49 ratings
# 41117     4.5 out of 5 stars3 ratings
# 29664       5 out of 5 stars3 ratings
# 21336     4.5 out of 5 stars2 ratings
# 48635        5 out of 5 stars1 rating
# 38950        4 out of 5 stars1 rating
# 59394       5 out of 5 stars8 ratings
# 79919     4.5 out of 5 stars4 ratings
# 60151     4.5 out of 5 stars9 ratings
# Name: stars, dtype: object

# %%
# Replace 'Not rate yet' with NaN
audible['stars'] = audible['stars'].replace('Not rated yet' , np.nan, inplace=True)

# %%
# Extract number of stars into rating_stars and turn into float
audible['rating_stars'] = audible['stars'].str.extract('^([\d.]+)').astype(float)

# Replace the comma, extract number of ratings into n_ratings and turn into float
audible['n_ratings'] = audible['stars'].str.replace(',', '').str.extract('(\d+) rating').astype(float)

# Examine the new rating_stars and n_ratings columns
audible[['rating_stars', 'n_ratings']]
# Out:
#        rating_stars  n_ratings
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN
# ...             ...        ...
# 87484           NaN        NaN
# 87485           NaN        NaN
# 87486           NaN        NaN
# 87487           NaN        NaN
# 87488           NaN        NaN
#
# [87489 rows x 2 columns]

# %%
# Drop the stars column
audible.drop(columns=['stars'], axis=1, inplace=True)
                      
# Check the results
audible.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator                time releasedate language   price  \
# 0      BillLobely   2 hrs and 20 mins    04-08-08  English  468.00
# 1   RobbieDaymond   13 hrs and 8 mins    01-05-18  English  820.00
# 2      DanRussell    2 hrs and 3 mins    06-11-20  English  410.00
# 3  SoneelaNankani  11 hrs and 16 mins    05-10-21  English  615.00
# 4  JesseBernstein              10 hrs    13-01-10  English  820.00
#
#    rating_stars  n_ratings
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %% [markdown]
# ## Task 4:
# Change data types

# %%
# Explore the price column
audible.price.sample(n=10)
# Out:
# 10308     93.00
# 12807    375.00
# 37478    516.00
# 68501    703.00
# 52871    401.00
# 69235    668.00
# 41969    500.00
# 27078    754.00
# 40014    221.00
# 86896    836.00
# Name: price, dtype: object

# %%
# Replace the comma with ' '
audible['price']=audible.price.str.replace(',', '')

# Replace 'Free' with 0
audible['price']=audible.price.str.replace('Free', '0')

# Turn price into float
audible['price'] = audible['price'].astype(float)

# %%
# Look at the unique values in the rating_stars column
audible.rating_stars.unique()
# Out:
# array([nan])

# %%
# Turn rating_stars to a category
audible['rating_stars'] = audible.rating_stars.astype('category')

# %%
# Convert release_date to datetime
audible['releasedate'] = pd.to_datetime(audible['releasedate'])

# Inspect the dataframe
audible.info()
# Out:
# /tmp/ipykernel_3428/3001827732.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   audible['releasedate'] = pd.to_datetime(audible['releasedate'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          87489 non-null  object
#  1   author        87489 non-null  object
#  2   narrator      87489 non-null  object
#  3   time          87489 non-null  object
#  4   releasedate   87489 non-null  datetime64[ns]
#  5   language      87489 non-null  object
#  6   price         87489 non-null  float64
#  7   rating_stars  0 non-null      category
#  8   n_ratings     0 non-null      float64
# dtypes: category(1), datetime64[ns](1), float64(2), object(5)
# memory usage: 5.4+ MB

# %% [markdown]
# ## Task 5:
# Extract hours and minutes from the `time` column

# %%
# Explore the values in the time column
audible.time.sample(n=10)
# Out:
# 23028     6 hrs and 49 mins
# 65943     4 hrs and 31 mins
# 57108      7 hrs and 3 mins
# 85854    11 hrs and 39 mins
# 58331     11 hrs and 4 mins
# 46103    12 hrs and 38 mins
# 84495     2 hrs and 45 mins
# 27093     7 hrs and 27 mins
# 12490               37 mins
# 3210      3 hrs and 27 mins
# Name: time, dtype: object

# %%
# Search entries for other ways to spell minutes
audible.time[audible.time.str.contains('minute')].sample(n=10)
# Out:
# 67097    Less than 1 minute
# 87070    Less than 1 minute
# 1404     Less than 1 minute
# 67108    Less than 1 minute
# 87058    Less than 1 minute
# 55648    Less than 1 minute
# 87180    Less than 1 minute
# 24070    Less than 1 minute
# 69297    Less than 1 minute
# 10886    Less than 1 minute
# Name: time, dtype: object

# %%
# Replace hrs, mins, and 'Less than 1 minute'
audible['time'] = audible.time.str.replace('hrs', 'h')
audible['time'] = audible.time.str.replace('mins', 'min')
audible['time'] = audible.time.str.replace('Less than 1 min', '1 min')

# %%
# Check the results
audible[['time']]
# Out:
#                   time
# 0       2 h and 20 min
# 1       13 h and 8 min
# 2        2 h and 3 min
# 3      11 h and 16 min
# 4                 10 h
# ...                ...
# 87484   7 h and 34 min
# 87485   10 h and 7 min
# 87486   19 h and 4 min
# 87487    4 h and 8 min
# 87488    6 h and 1 min
#
# [87489 rows x 1 columns]

# %%
# Extract the number of hours, turn to integer
hours = audible['time'].str.extract('(\d+) hr').fillna(0).astype(int)

# Extract the number of minutes, turn to integer
mins = audible['time'].str.extract('(\d+) min').fillna(0).astype(int)

# Combine hours and minutes into the time_mins column
audible['time_mins'] = hours * 60 + mins

# Check the results
audible[['time_mins']]
# Out:
#        time_mins
# 0             20
# 1              8
# 2              3
# 3             16
# 4              0
# ...          ...
# 87484         34
# 87485          7
# 87486          4
# 87487          8
# 87488          1
#
# [87489 rows x 1 columns]

# %%
# Drop the time column
audible.drop(columns=['time'], axis=1, inplace=True)

# %%
# Inspect the dataframe
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          87489 non-null  object
#  1   author        87489 non-null  object
#  2   narrator      87489 non-null  object
#  3   releasedate   87489 non-null  datetime64[ns]
#  4   language      87489 non-null  object
#  5   price         87489 non-null  float64
#  6   rating_stars  0 non-null      category
#  7   n_ratings     0 non-null      float64
#  8   time_mins     87489 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 5.4+ MB

# %%
# Plot histogram of all the numericl columns
audible.hist(figsize=(10,10), bins=60)
plt.show()

# %%
# look at the numeric columns
audible.describe()
# Out:
#                          releasedate         price  n_ratings     time_mins
# count                          87489  87489.000000        0.0  87489.000000
# mean   2018-06-22 01:35:29.780886528    559.009246        NaN     32.736835
# min              1998-12-27 00:00:00      0.000000        NaN      0.000000
# 25%              2016-08-30 00:00:00    268.000000        NaN     15.000000
# 50%              2020-01-30 00:00:00    585.000000        NaN     30.000000
# 75%              2021-08-04 00:00:00    755.000000        NaN     47.000000
# max              2025-11-14 00:00:00   7198.000000        NaN    119.000000
# std                              NaN    336.096642        NaN     22.712796

# %%
# look at the non numeric columns
audible.describe(exclude=[np.number])
# Out:
#                   name    author   narrator                    releasedate  \
# count            87489     87489      87489                          87489
# unique           82767     48374      29717                            NaN
# top     The Art of War  矢島雅弘,石橋遊  anonymous                            NaN
# freq                20       874       1034                            NaN
# mean               NaN       NaN        NaN  2018-06-22 01:35:29.780886528
# min                NaN       NaN        NaN            1998-12-27 00:00:00
# 25%                NaN       NaN        NaN            2016-08-30 00:00:00
# 50%                NaN       NaN        NaN            2020-01-30 00:00:00
# 75%                NaN       NaN        NaN            2021-08-04 00:00:00
# max                NaN       NaN        NaN            2025-11-14 00:00:00
#
#        language rating_stars
# count     87489            0
# unique       36            0
# top     English          NaN
# freq      61884          NaN
# mean        NaN          NaN
# min         NaN          NaN
# 25%         NaN          NaN
# 50%         NaN          NaN
# 75%         NaN          NaN
# max         NaN          NaN

# %%
# Transform prices to USD (multiply times 0.012)
audible['price'] = audible['price'] * 0.012

# Check the results
audible.price.describe()
# Out:
# count    87489.000000
# mean         6.708111
# std          4.033160
# min          0.000000
# 25%          3.216000
# 50%          7.020000
# 75%          9.060000
# max         86.376000
# Name: price, dtype: float64

# %%
# Inspect the language column before making changes
audible.language.unique()
# Out:
# array(['English', 'Hindi', 'spanish', 'german', 'french', 'catalan',
#        'swedish', 'italian', 'danish', 'finnish', 'dutch', 'hebrew',
#        'russian', 'polish', 'galician', 'afrikaans', 'icelandic',
#        'romanian', 'japanese', 'tamil', 'portuguese', 'urdu', 'hungarian',
#        'czech', 'bulgarian', 'mandarin_chinese', 'basque', 'korean',
#        'arabic', 'greek', 'turkish', 'ukrainian', 'slovene', 'norwegian',
#        'telugu', 'lithuanian'], dtype=object)

# %%
# update capitalization in the language column
audible['language'] = audible['language'].str.capitalize()

# Check the results
audible.language.unique()
# Out:
# array(['English', 'Hindi', 'Spanish', 'German', 'French', 'Catalan',
#        'Swedish', 'Italian', 'Danish', 'Finnish', 'Dutch', 'Hebrew',
#        'Russian', 'Polish', 'Galician', 'Afrikaans', 'Icelandic',
#        'Romanian', 'Japanese', 'Tamil', 'Portuguese', 'Urdu', 'Hungarian',
#        'Czech', 'Bulgarian', 'Mandarin_chinese', 'Basque', 'Korean',
#        'Arabic', 'Greek', 'Turkish', 'Ukrainian', 'Slovene', 'Norwegian',
#        'Telugu', 'Lithuanian'], dtype=object)

# %% [markdown]
# ## Task 7:
# Checking for duplicates

# %%
# Look for duplicate rows
audible.duplicated().sum()
# Out:
# 40

# %%
# Create a list of our subset of columns and assign to subset_cols
subset_cols = ['name', 'author', 'narrator', 'time_mins', 'price']

# Check for duplicates using our subset of columns
audible.duplicated(subset=subset_cols).sum()
# Out:
# 71

# %%
# Check the duplicated rows keeping the duplicates and order by the name column
audible[audible.duplicated(subset=subset_cols, keep=False)].sort_values('name')
# Out:
#                                               name                    author  \
# 63965      "Das Böse ist des Menschen beste Kraft"         ChristianLiederer
# 63978      "Das Böse ist des Menschen beste Kraft"         ChristianLiederer
# 24625                         90 Minutes in Heaven     DonPiper,CecilMurphey
# 24116                         90 Minutes in Heaven     DonPiper,CecilMurphey
# 16964                                 Adagio in Dm                 BillBrown
# ...                                            ...                       ...
# 33922  What I Talk About When I Talk About Running            HarukiMurakami
# 38021                   When Women Ruled the World                KaraCooney
# 20260                   When Women Ruled the World                KaraCooney
# 22158                                Wings of Fire  APJAbdulKalam,ArunTiwari
# 64428                                Wings of Fire  APJAbdulKalam,ArunTiwari
#
#            narrator releasedate language   price rating_stars  n_ratings  \
# 63965  ThomasKrause  2021-12-23   German   2.796          NaN        NaN
# 63978  ThomasKrause  2021-12-14   German   2.796          NaN        NaN
# 24625      DonPiper  2015-09-25  English   7.032          NaN        NaN
# 24116      DonPiper  2020-10-15  English   7.032          NaN        NaN
# 16964     BillBrown  2021-08-17  English   5.472          NaN        NaN
# ...             ...         ...      ...     ...          ...        ...
# 33922     RayPorter  2016-07-07  English   4.776          NaN        NaN
# 38021    KaraCooney  2018-11-30  English  10.032          NaN        NaN
# 20260    KaraCooney  2018-11-30  English  10.032          NaN        NaN
# 22158  GirishKarnad  2020-01-04  English   0.900          NaN        NaN
# 64428  GirishKarnad  2020-01-04  English   0.900          NaN        NaN
#
#        time_mins
# 63965         24
# 63978         24
# 24625         15
# 24116         15
# 16964         78
# ...          ...
# 33922         23
# 38021         15
# 20260         15
# 22158         75
# 64428         75
#
# [141 rows x 9 columns]

# %%
# Drop the duplicated rows keeping the last release date
audible.drop_duplicates(subset=subset_cols, keep='last', inplace=True)

# %%
# Checking again for duplicates using our subset of columns
audible.duplicated(subset=subset_cols).sum()
# Out:
# 0

# %% [markdown]
# ## Task 8:
# Dealing with missing data

# %%
# Check for null values
audible.isnull().sum()
# Out:
# name                0
# author              0
# narrator            0
# releasedate         0
# language            0
# price               0
# rating_stars    87418
# n_ratings       87418
# time_mins           0
# dtype: int64

# %% [markdown]
# ## Task 9:
# Save the cleaned data set

# %%
# Save the dataframe to a new csv file 'audible_clean.csv'
audible.to_csv('data/audible_clean.csv', index=False)

# %%
# Load the audible_cleaned.csv file
audible3 = pd.read_csv('data/audible_clean.csv')

# View the first rows of the dataframe
audible3.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator releasedate language  price  rating_stars  n_ratings  \
# 0      BillLobely  2008-04-08  English  5.616           NaN        NaN
# 1   RobbieDaymond  2018-01-05  English  9.840           NaN        NaN
# 2      DanRussell  2020-06-11  English  4.920           NaN        NaN
# 3  SoneelaNankani  2021-05-10  English  7.380           NaN        NaN
# 4  JesseBernstein  2010-01-13  English  9.840           NaN        NaN
#
#    time_mins
# 0         20
# 1          8
# 2          3
# 3         16
# 4          0
